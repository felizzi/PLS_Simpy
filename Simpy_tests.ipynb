# %% [markdown]
# <a href="https://colab.research.google.com/github/felizzi/PLS_Simpy/blob/main/Simpy_tests.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install simpy
# Out:
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
import simpy
import random

class Patient:
    def __init__(self, name, env, resource):
        self.name = name
        self.env = env
        self.resource = resource
        self.action = env.process(self.visit_hospital())

    def visit_hospital(self):
        print(f"{self.name} arrives at the hospital at {self.env.now}")

        # Request a bed in the hospital
        with self.resource.request() as req:
            yield req
            print(f"{self.name} gets a bed at {self.env.now}")

            # The amount of time the patient spends in the bed
            treatment_time = random.randint(5, 20)
            yield self.env.timeout(treatment_time)

            print(f"{self.name} leaves the hospital at {self.env.now}")

# Initialize the SimPy environment
env = simpy.Environment()

# Create a resource with 3 beds
beds = simpy.Resource(env, capacity=3)

# Generate 5 patients
for i in range(5):
    patient_name = f"Patient-{i}"
    Patient(patient_name, env, beds)

# Run the simulation
env.run()
# Out:
# Patient-0 arrives at the hospital at 0
# Patient-1 arrives at the hospital at 0
# Patient-2 arrives at the hospital at 0
# Patient-3 arrives at the hospital at 0
# Patient-4 arrives at the hospital at 0
# Patient-0 gets a bed at 0
# Patient-1 gets a bed at 0
# Patient-2 gets a bed at 0
# Patient-0 leaves the hospital at 5
# Patient-3 gets a bed at 5
# Patient-2 leaves the hospital at 17
# Patient-4 gets a bed at 17
# Patient-1 leaves the hospital at 20
# Patient-3 leaves the hospital at 21
# Patient-4 leaves the hospital at 35

# %%
import simpy
import random

# Initialize variables to hold total waiting times and number of patients
total_doctor_wait = 0
num_doctor_visits = 0
waiting_time_threshold = 8  # Threshold for average waiting time (in arbitrary time units)

def monitor(env, doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits == 0:
            continue
        avg_wait_time = total_doctor_wait / num_doctor_visits
        print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
        if avg_wait_time > waiting_time_threshold:
            doctor.capacity += 1  # Add an extra doctor
            print(f"Added an extra doctor at {env.now}, new capacity: {doctor.capacity}")

def patient(env, name, doctor):
    global total_doctor_wait, num_doctor_visits

    arrival_time = env.now
    with doctor.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        num_doctor_visits += 1
        print(f"{name} starts consultation at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")

# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor resource with initial capacity of 1
doctor = simpy.Resource(env, capacity=1)

# Start the monitoring process
env.process(monitor(env, doctor))

# Generate patients
for i in range(20):
    env.process(patient(env, f"Patient-{i}", doctor))
    next_patient_in = random.randint(1, 4)
    #yield env.timeout(next_patient_in)

# Run the simulation
env.run(until=100)
# Out:
# Patient-0 starts consultation at 0, waited 0
# Patient-0 finishes consultation at 5
# Patient-1 starts consultation at 5, waited 5
# Average doctor waiting time at 10 is 2.5
# Patient-1 finishes consultation at 15
# Patient-2 starts consultation at 15, waited 15
# Average doctor waiting time at 20 is 6.666666666666667
# Patient-2 finishes consultation at 24
# Patient-3 starts consultation at 24, waited 24
# Average doctor waiting time at 30 is 11.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1aaf4134ddfa> in monitor(env, doctor)
#      17         if avg_wait_time > waiting_time_threshold:
# ---> 18             doctor.capacity += 1  # Add an extra doctor
#      19             print(f"Added an extra doctor at {env.now}, new capacity: {doctor.capacity}")
#
# AttributeError: can't set attribute 'capacity'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-1aaf4134ddfa> in <cell line: 50>()
#      48
#      49 # Run the simulation
# ---> 50 env.run(until=100)
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in run(self, until)
#     253         try:
#     254             while True:
# --> 255                 self.step()
#     256         except StopSimulation as exc:
#     257             return exc.args[0]  # == until.value
#
# /usr/local/lib/python3.10/dist-packages/simpy/core.py in step(self)
#     205             exc = type(event._value)(*event._value.args)
#     206             exc.__cause__ = event._value
# --> 207             raise exc
#     208
#     209     def run(
#
# AttributeError: can't set attribute 'capacity'

# %%
import simpy
import random

# Initialize variables to hold total waiting times
total_registration_wait = 0
total_doctor_wait = 0
total_pharmacy_wait = 0
total_patients = 5

def patient(env, name, registration, doctor, pharmacy):
    global total_registration_wait, total_doctor_wait, total_pharmacy_wait

    print(f"{name} enters the hospital at {env.now}")

    # Step 1: Registration
    arrival_time = env.now
    with registration.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_registration_wait += wait_time
        print(f"{name} starts registration at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(1, 3))
        print(f"{name} finishes registration at {env.now}")

    # Step 2: Doctor Consultation
    arrival_time = env.now
    with doctor.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        print(f"{name} starts consultation at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")

    # Step 3: Pharmacy
    arrival_time = env.now
    with pharmacy.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_pharmacy_wait += wait_time
        print(f"{name} starts medication pickup at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(2, 5))
        print(f"{name} finishes medication pickup and leaves the hospital at {env.now}")

# Initialize SimPy environment
env = simpy.Environment()

# Initialize resources: registration desk, doctor, and pharmacy
registration = simpy.Resource(env, capacity=1)
doctor = simpy.Resource(env, capacity=1)
pharmacy = simpy.Resource(env, capacity=1)

# Generate 5 patients
for i in range(total_patients):
    env.process(patient(env, f"Patient-{i}", registration, doctor, pharmacy))

# Run the simulation
env.run()

# Calculate average waiting time for each resource
print("\nAverage waiting times:")
print(f"Registration: {total_registration_wait / total_patients:.2f}")
print(f"Doctor: {total_doctor_wait / total_patients:.2f}")
print(f"Pharmacy: {total_pharmacy_wait / total_patients:.2f}")
# Out:
# Patient-0 enters the hospital at 0
# Patient-1 enters the hospital at 0
# Patient-2 enters the hospital at 0
# Patient-3 enters the hospital at 0
# Patient-4 enters the hospital at 0
# Patient-0 starts registration at 0, waited 0
# Patient-0 finishes registration at 1
# Patient-0 starts consultation at 1, waited 0
# Patient-1 starts registration at 1, waited 1
# Patient-1 finishes registration at 4
# Patient-2 starts registration at 4, waited 4
# Patient-2 finishes registration at 5
# Patient-3 starts registration at 5, waited 5
# Patient-3 finishes registration at 8
# Patient-4 starts registration at 8, waited 8
# Patient-0 finishes consultation at 9
# Patient-0 starts medication pickup at 9, waited 0
# Patient-1 starts consultation at 9, waited 5
# Patient-4 finishes registration at 11
# Patient-0 finishes medication pickup and leaves the hospital at 11
# Patient-1 finishes consultation at 15
# Patient-1 starts medication pickup at 15, waited 0
# Patient-2 starts consultation at 15, waited 10
# Patient-1 finishes medication pickup and leaves the hospital at 17
# Patient-2 finishes consultation at 22
# Patient-2 starts medication pickup at 22, waited 0
# Patient-3 starts consultation at 22, waited 14
# Patient-2 finishes medication pickup and leaves the hospital at 25
# Patient-3 finishes consultation at 31
# Patient-3 starts medication pickup at 31, waited 0
# Patient-4 starts consultation at 31, waited 20
# Patient-3 finishes medication pickup and leaves the hospital at 36
# Patient-4 finishes consultation at 37
# Patient-4 starts medication pickup at 37, waited 0
# Patient-4 finishes medication pickup and leaves the hospital at 39
#
# Average waiting times:
# Registration: 3.60
# Doctor: 9.80
# Pharmacy: 0.00

# %%
import simpy
import random

total_doctor_wait = 0
num_doctor_visits = 0
waiting_time_threshold = 8  # Time units

class Doctor(simpy.Resource):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)

    def add_doctor(self):
        self._capacity += 1

def monitor(env, doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits > 0:
            avg_wait_time = total_doctor_wait / num_doctor_visits
            print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
            if avg_wait_time > waiting_time_threshold:
                doctor.add_doctor()
                print(f"Added an extra doctor at {env.now}, new capacity: {doctor.capacity}")

def patient(env, name, doctor):
    global total_doctor_wait, num_doctor_visits

    arrival_time = env.now
    with doctor.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        num_doctor_visits += 1
        print(f"{name} starts consultation at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")



def generate_patients(env, doctor):
    for i in range(20):
        env.process(patient(env, f"Patient-{i}", doctor))
        next_patient_in = random.randint(1, 4)
        yield env.timeout(next_patient_in)

# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor resource with initial capacity of 1
doctor = Doctor(env, capacity=1)

# Start the monitoring process
env.process(monitor(env, doctor))

# Start the patient generation process
env.process(generate_patients(env, doctor))

# Run the simulation until a specified time
env.run(until=100)
# Out:
# Patient-0 starts consultation at 0, waited 0
# Patient-0 finishes consultation at 8
# Patient-1 starts consultation at 8, waited 7
# Average doctor waiting time at 10 is 3.5
# Patient-1 finishes consultation at 18
# Patient-2 starts consultation at 18, waited 15
# Average doctor waiting time at 20 is 7.333333333333333
# Patient-2 finishes consultation at 25
# Patient-3 starts consultation at 25, waited 20
# Average doctor waiting time at 30 is 10.5
# Added an extra doctor at 30, new capacity: 2
# Patient-4 starts consultation at 30, waited 23
# Patient-3 finishes consultation at 34
# Patient-5 starts consultation at 34, waited 26
# Patient-4 finishes consultation at 38
# Patient-6 starts consultation at 38, waited 26
# Average doctor waiting time at 40 is 16.714285714285715
# Added an extra doctor at 40, new capacity: 3
# Patient-7 starts consultation at 41, waited 27
# Patient-5 finishes consultation at 43
# Patient-8 starts consultation at 43, waited 25
# Patient-6 finishes consultation at 48
# Patient-9 starts consultation at 48, waited 26
# Patient-7 finishes consultation at 49
# Patient-10 starts consultation at 49, waited 25
# Average doctor waiting time at 50 is 20.0
# Added an extra doctor at 50, new capacity: 4
# Patient-8 finishes consultation at 52
# Patient-11 starts consultation at 52, waited 27
# Patient-10 finishes consultation at 54
# Patient-12 starts consultation at 54, waited 28
# Patient-9 finishes consultation at 57
# Patient-13 starts consultation at 57, waited 27
# Average doctor waiting time at 60 is 21.571428571428573
# Added an extra doctor at 60, new capacity: 5
# Patient-12 finishes consultation at 60
# Patient-14 starts consultation at 60, waited 29
# Patient-11 finishes consultation at 62
# Patient-15 starts consultation at 62, waited 30
# Patient-13 finishes consultation at 64
# Patient-16 starts consultation at 64, waited 31
# Patient-14 finishes consultation at 68
# Patient-17 starts consultation at 68, waited 32
# Patient-16 finishes consultation at 69
# Patient-18 starts consultation at 69, waited 30
# Average doctor waiting time at 70 is 23.894736842105264
# Added an extra doctor at 70, new capacity: 6
# Patient-15 finishes consultation at 70
# Patient-19 starts consultation at 70, waited 29
# Patient-18 finishes consultation at 74
# Patient-19 finishes consultation at 76
# Patient-17 finishes consultation at 78
# Average doctor waiting time at 80 is 24.15
# Added an extra doctor at 80, new capacity: 7
# Average doctor waiting time at 90 is 24.15
# Added an extra doctor at 90, new capacity: 8

# %%
import simpy
import random

total_doctor_wait = 0
num_doctor_visits = 0
waiting_time_threshold = 8  # Time units

class Doctor(simpy.Resource):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "General"

    def add_doctor(self):
        self._capacity += 1

class SpecialistDoctor(Doctor):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "Specialist"

def monitor(env, doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits > 0:
            avg_wait_time = total_doctor_wait / num_doctor_visits
            print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
            if avg_wait_time > waiting_time_threshold:
                doctor.add_doctor()
                if doctor.doctor_type == "General":
                    doctor.__class__ = SpecialistDoctor
                print(f"Added an extra {doctor.doctor_type} doctor at {env.now}, new capacity: {doctor.capacity}")

def patient(env, name, doctor):
    global total_doctor_wait, num_doctor_visits

    arrival_time = env.now
    with doctor.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        num_doctor_visits += 1
        print(f"{name} starts consultation with {doctor.doctor_type} at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")

def generate_patients(env, doctor):
    for i in range(20):
        env.process(patient(env, f"Patient-{i}", doctor))
        next_patient_in = random.randint(1, 4)
        yield env.timeout(next_patient_in)

# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor resource with initial capacity of 1
doctor = Doctor(env, capacity=1)

# Start the monitoring process
env.process(monitor(env, doctor))

# Start the patient generation process
env.process(generate_patients(env, doctor))

# Run the simulation until a specified time
env.run(until=100)
# Out:
# Patient-0 starts consultation with General at 0, waited 0
# Patient-0 finishes consultation at 6
# Patient-1 starts consultation with General at 6, waited 4
# Average doctor waiting time at 10 is 2.0
# Patient-1 finishes consultation at 11
# Patient-2 starts consultation with General at 11, waited 8
# Patient-2 finishes consultation at 17
# Patient-3 starts consultation with General at 17, waited 10
# Average doctor waiting time at 20 is 5.5
# Patient-3 finishes consultation at 27
# Patient-4 starts consultation with General at 27, waited 17
# Average doctor waiting time at 30 is 7.8
# Patient-4 finishes consultation at 35
# Patient-5 starts consultation with General at 35, waited 22
# Average doctor waiting time at 40 is 10.166666666666666
# Added an extra General doctor at 40, new capacity: 2
# Patient-6 starts consultation with General at 40, waited 25
# Patient-5 finishes consultation at 45
# Patient-7 starts consultation with General at 45, waited 29
# Patient-6 finishes consultation at 47
# Patient-8 starts consultation with General at 47, waited 29
# Average doctor waiting time at 50 is 16.0
# Added an extra General doctor at 50, new capacity: 3
# Patient-7 finishes consultation at 50
# Patient-9 starts consultation with General at 50, waited 28
# Patient-9 finishes consultation at 55
# Patient-10 starts consultation with General at 55, waited 32
# Patient-8 finishes consultation at 57
# Patient-11 starts consultation with General at 57, waited 31
# Average doctor waiting time at 60 is 19.583333333333332
# Added an extra General doctor at 60, new capacity: 4
# Patient-10 finishes consultation at 62
# Patient-12 starts consultation with General at 62, waited 33
# Patient-11 finishes consultation at 65
# Patient-13 starts consultation with General at 65, waited 35
# Average doctor waiting time at 70 is 21.642857142857142
# Added an extra General doctor at 70, new capacity: 5
# Patient-12 finishes consultation at 71
# Patient-14 starts consultation with General at 71, waited 39
# Patient-13 finishes consultation at 72
# Patient-15 starts consultation with General at 72, waited 39
# Patient-15 finishes consultation at 78
# Patient-16 starts consultation with General at 78, waited 42
# Average doctor waiting time at 80 is 24.88235294117647
# Added an extra General doctor at 80, new capacity: 6
# Patient-14 finishes consultation at 81
# Patient-17 starts consultation with General at 81, waited 41
# Patient-16 finishes consultation at 85
# Patient-18 starts consultation with General at 85, waited 44
# Patient-17 finishes consultation at 86
# Patient-19 starts consultation with General at 86, waited 42
# Average doctor waiting time at 90 is 27.5
# Added an extra General doctor at 90, new capacity: 7
# Patient-18 finishes consultation at 93
# Patient-19 finishes consultation at 93

# %%
# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor resource with initial capacity of 1
doctor = Doctor(env, capacity=2)

# Initialize specialist doctor resource with initial capacity of 0
specialist_doctor = SpecialistDoctor(env, capacity=1)

def monitor(env, doctor, specialist_doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits > 0:
            avg_wait_time = total_doctor_wait / num_doctor_visits
            print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
            if avg_wait_time > waiting_time_threshold:
                specialist_doctor.add_doctor()
                print(f"Added an extra {specialist_doctor.doctor_type} doctor at {env.now}, new capacity: {specialist_doctor.capacity}")

def generate_patients(env, doctor, specialist_doctor):
    for i in range(50):  # Increased patient count
        if specialist_doctor.capacity > 0 and random.random() < 0.5:
            env.process(patient(env, f"Patient-{i}", specialist_doctor))
        else:
            env.process(patient(env, f"Patient-{i}", doctor))

        next_patient_in = random.randint(1, 4)
        yield env.timeout(next_patient_in)

# Start the monitoring process
env.process(monitor(env, doctor, specialist_doctor))

# Start the patient generation process
env.process(generate_patients(env, doctor, specialist_doctor))

# Run the simulation until a specified time
env.run(until=200)  # Increased simulation time
# Out:
# Patient-0 starts consultation with General at 0, waited 0
# Patient-1 starts consultation with General at 3, waited 0
# Patient-0 finishes consultation at 5
# Patient-2 starts consultation with Specialist at 7, waited 0
# Average doctor waiting time at 10 is 6.164383561643835
# Patient-4 starts consultation with General at 11, waited 0
# Patient-1 finishes consultation at 12
# Patient-2 finishes consultation at 16
# Patient-4 finishes consultation at 16
# Patient-3 starts consultation with Specialist at 16, waited 8
# Patient-6 starts consultation with General at 18, waited 0
# Average doctor waiting time at 20 is 6.026315789473684
# Patient-8 starts consultation with General at 21, waited 0
# Patient-6 finishes consultation at 23
# Patient-9 starts consultation with General at 23, waited 1
# Patient-3 finishes consultation at 24
# Patient-5 starts consultation with Specialist at 24, waited 9
# Patient-5 finishes consultation at 29
# Patient-7 starts consultation with Specialist at 29, waited 9
# Average doctor waiting time at 30 is 5.9625
# Patient-8 finishes consultation at 31
# Patient-11 starts consultation with General at 31, waited 5
# Patient-9 finishes consultation at 32
# Patient-7 finishes consultation at 36
# Patient-10 starts consultation with Specialist at 36, waited 12
# Average doctor waiting time at 40 is 6.024390243902439
# Patient-11 finishes consultation at 40
# Patient-15 starts consultation with General at 40, waited 0
# Patient-16 starts consultation with General at 41, waited 0
# Patient-10 finishes consultation at 43
# Patient-12 starts consultation with Specialist at 43, waited 13
# Patient-15 finishes consultation at 48
# Patient-16 finishes consultation at 49
# Average doctor waiting time at 50 is 5.964705882352941
# Patient-12 finishes consultation at 50
# Patient-19 starts consultation with General at 50, waited 0
# Patient-13 starts consultation with Specialist at 50, waited 18
# Patient-20 starts consultation with General at 53, waited 0
# Patient-13 finishes consultation at 57
# Patient-14 starts consultation with Specialist at 57, waited 21
# Patient-20 finishes consultation at 59
# Patient-21 starts consultation with General at 59, waited 2
# Average doctor waiting time at 60 is 6.088888888888889
# Patient-19 finishes consultation at 60
# Patient-22 starts consultation with General at 60, waited 0
# Patient-14 finishes consultation at 64
# Patient-21 finishes consultation at 64
# Patient-17 starts consultation with Specialist at 64, waited 20
# Patient-24 starts consultation with General at 65, waited 0
# Patient-22 finishes consultation at 66
# Patient-17 finishes consultation at 69
# Patient-18 starts consultation with Specialist at 69, waited 22
# Average doctor waiting time at 70 is 6.276595744680851
# Patient-26 starts consultation with General at 71, waited 0
# Patient-24 finishes consultation at 74
# Patient-18 finishes consultation at 78
# Patient-23 starts consultation with Specialist at 78, waited 14
# Average doctor waiting time at 80 is 6.291666666666667
# Patient-29 starts consultation with General at 80, waited 0
# Patient-26 finishes consultation at 81
# Patient-23 finishes consultation at 84
# Patient-25 starts consultation with Specialist at 84, waited 15
# Patient-31 starts consultation with General at 86, waited 0
# Patient-29 finishes consultation at 89
# Average doctor waiting time at 90 is 6.252525252525253
# Patient-25 finishes consultation at 90
# Patient-32 starts consultation with General at 90, waited 0
# Patient-27 starts consultation with Specialist at 90, waited 15
# Patient-31 finishes consultation at 95
# Patient-32 finishes consultation at 98
# Patient-35 starts consultation with General at 98, waited 0
# Average doctor waiting time at 100 is 6.215686274509804
# Patient-27 finishes consultation at 100
# Patient-28 starts consultation with Specialist at 100, waited 23
# Patient-37 starts consultation with General at 103, waited 0
# Patient-35 finishes consultation at 107
# Patient-28 finishes consultation at 109
# Patient-30 starts consultation with Specialist at 109, waited 25
# Average doctor waiting time at 110 is 6.495238095238095
# Patient-37 finishes consultation at 113
# Patient-43 starts consultation with General at 113, waited 0
# Patient-30 finishes consultation at 118
# Patient-45 starts consultation with General at 118, waited 0
# Patient-33 starts consultation with Specialist at 118, waited 24
# Average doctor waiting time at 120 is 6.537037037037037
# Patient-43 finishes consultation at 121
# Patient-46 starts consultation with General at 121, waited 0
# Patient-33 finishes consultation at 123
# Patient-34 starts consultation with Specialist at 123, waited 28
# Patient-45 finishes consultation at 127
# Patient-34 finishes consultation at 128
# Patient-36 starts consultation with Specialist at 128, waited 27
# Average doctor waiting time at 130 is 6.8558558558558556
# Patient-46 finishes consultation at 131
# Patient-36 finishes consultation at 136
# Patient-38 starts consultation with Specialist at 136, waited 31
# Average doctor waiting time at 140 is 7.071428571428571
# Patient-38 finishes consultation at 144
# Patient-39 starts consultation with Specialist at 144, waited 38
# Average doctor waiting time at 150 is 7.345132743362832
# Patient-39 finishes consultation at 151
# Patient-40 starts consultation with Specialist at 151, waited 44
# Patient-40 finishes consultation at 159
# Patient-41 starts consultation with Specialist at 159, waited 50
# Average doctor waiting time at 160 is 8.034782608695652
# Added an extra Specialist doctor at 160, new capacity: 2
# Patient-41 finishes consultation at 166
# Patient-42 starts consultation with Specialist at 166, waited 55
# Average doctor waiting time at 170 is 8.439655172413794
# Added an extra Specialist doctor at 170, new capacity: 3
# Patient-42 finishes consultation at 172
# Patient-44 starts consultation with Specialist at 172, waited 58
# Average doctor waiting time at 180 is 8.863247863247864
# Added an extra Specialist doctor at 180, new capacity: 4
# Patient-44 finishes consultation at 180
# Patient-47 starts consultation with Specialist at 180, waited 55
# Patient-47 finishes consultation at 187
# Patient-48 starts consultation with Specialist at 187, waited 61
# Average doctor waiting time at 190 is 9.6890756302521
# Added an extra Specialist doctor at 190, new capacity: 5
# Patient-48 finishes consultation at 193
# Patient-49 starts consultation with Specialist at 193, waited 63
# Patient-49 finishes consultation at 198

# %%
import simpy

def resource_user(env, resource, priority):
    while True:  # Continue trying to use the resource until successful
        try:
            with resource.request(priority=priority) as req:
                yield req  # Wait until the resource is available or the process is preempted
                print(f"Resource being used with priority {priority} at {env.now}")
                yield env.timeout(2)  # Use the resource for 2 time units
                print(f"Resource released with priority {priority} at {env.now}")
                break  # Exit the while loop once the resource use is complete
        except simpy.Interrupt as interrupt:
            # Handle preemption
            print(f"Process with priority {priority} was preempted at {env.now} by {interrupt.cause}")

env = simpy.Environment()
resource = simpy.PreemptiveResource(env, capacity=1)

# Start processes with different priorities
env.process(resource_user(env, resource, priority=1))  # Lower priority process
env.process(resource_user(env, resource, priority=0))  # Higher priority process

# Run the simulation
env.run()
# Out:
# Process with priority 1 was preempted at 0 by <simpy.resources.resource.Preempted object at 0x7cedb8408430>
# Resource being used with priority 0 at 0
# Resource released with priority 0 at 2
# Resource being used with priority 1 at 2
# Resource released with priority 1 at 4

# %%
import simpy
import random

total_doctor_wait = 0
num_doctor_visits = 0
waiting_time_threshold = 8  # Time units

class Doctor:
    def __init__(self, env, capacity):
        self.resource = simpy.Resource(env, capacity)
        self.doctor_type = "General"

class SpecialistDoctor(Doctor):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "Specialist"

def monitor(env, doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits > 0:
            avg_wait_time = total_doctor_wait / num_doctor_visits
            print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
            if avg_wait_time > waiting_time_threshold and doctor.doctor_type == "General":
                doctor.__class__ = SpecialistDoctor
                print(f"Changed doctor type to {doctor.doctor_type} at {env.now}")

def patient(env, name, doctor):
    global total_doctor_wait, num_doctor_visits

    arrival_time = env.now
    with doctor.resource.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        num_doctor_visits += 1
        print(f"{name} starts consultation with {doctor.doctor_type} at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")

def generate_patients(env, doctor):
    for i in range(50):
        env.process(patient(env, f"Patient-{i}", doctor))
        next_patient_in = random.randint(1, 4)
        yield env.timeout(next_patient_in)

# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor with initial capacity of 1
doctor = Doctor(env, capacity=1)

# Start the monitoring process
env.process(monitor(env, doctor))

# Start the patient generation process
env.process(generate_patients(env, doctor))

# Run the simulation until a specified time
env.run(until=100)
# Out:
# Patient-0 starts consultation with General at 0, waited 0
# Average doctor waiting time at 10 is 0.0
# Patient-0 finishes consultation at 10
# Patient-1 starts consultation with General at 10, waited 6
# Average doctor waiting time at 20 is 3.0
# Patient-1 finishes consultation at 20
# Patient-2 starts consultation with General at 20, waited 15
# Patient-2 finishes consultation at 28
# Patient-3 starts consultation with General at 28, waited 20
# Average doctor waiting time at 30 is 10.25
# Changed doctor type to General at 30
# Patient-3 finishes consultation at 35
# Patient-4 starts consultation with General at 35, waited 23
# Average doctor waiting time at 40 is 12.8
# Changed doctor type to General at 40
# Patient-4 finishes consultation at 44
# Patient-5 starts consultation with General at 44, waited 28
# Patient-5 finishes consultation at 49
# Patient-6 starts consultation with General at 49, waited 30
# Average doctor waiting time at 50 is 17.428571428571427
# Changed doctor type to General at 50
# Patient-6 finishes consultation at 59
# Patient-7 starts consultation with General at 59, waited 38
# Average doctor waiting time at 60 is 20.0
# Changed doctor type to General at 60
# Patient-7 finishes consultation at 67
# Patient-8 starts consultation with General at 67, waited 43
# Average doctor waiting time at 70 is 22.555555555555557
# Changed doctor type to General at 70
# Patient-8 finishes consultation at 76
# Patient-9 starts consultation with General at 76, waited 51
# Average doctor waiting time at 80 is 25.4
# Changed doctor type to General at 80
# Patient-9 finishes consultation at 85
# Patient-10 starts consultation with General at 85, waited 57
# Average doctor waiting time at 90 is 28.272727272727273
# Changed doctor type to General at 90
# Patient-10 finishes consultation at 91
# Patient-11 starts consultation with General at 91, waited 62
# Patient-11 finishes consultation at 97
# Patient-12 starts consultation with General at 97, waited 64

# %%
import simpy
import random

total_doctor_wait = 0
num_doctor_visits = 0
waiting_time_threshold = 8  # Time units

class Doctor:
    def __init__(self, env, capacity):
        self.resource = simpy.Resource(env, capacity)
        self.doctor_type = "General"

class SpecialistDoctor(Doctor):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "Specialist"

def monitor(env, doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits > 0:
            avg_wait_time = total_doctor_wait / num_doctor_visits
            print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
            if avg_wait_time > waiting_time_threshold:
                doctor.__class__ = SpecialistDoctor
                doctor.doctor_type = "Specialist"
                print(f"Changed doctor type to {doctor.doctor_type} at {env.now}")

def patient(env, name, doctor):
    global total_doctor_wait, num_doctor_visits

    arrival_time = env.now
    with doctor.resource.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        num_doctor_visits += 1
        print(f"{name} starts consultation with {doctor.doctor_type} at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")

def generate_patients(env, doctor):
    for i in range(50):
        env.process(patient(env, f"Patient-{i}", doctor))
        next_patient_in = random.randint(1, 4)
        yield env.timeout(next_patient_in)

# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor with initial capacity of 1
doctor = Doctor(env, capacity=1)

# Start the monitoring process
env.process(monitor(env, doctor))

# Start the patient generation process
env.process(generate_patients(env, doctor))

# Run the simulation until a specified time
env.run(until=100)
# Out:
# Patient-0 starts consultation with General at 0, waited 0
# Average doctor waiting time at 10 is 0.0
# Patient-0 finishes consultation at 10
# Patient-1 starts consultation with General at 10, waited 8
# Patient-1 finishes consultation at 17
# Patient-2 starts consultation with General at 17, waited 14
# Average doctor waiting time at 20 is 7.333333333333333
# Patient-2 finishes consultation at 22
# Patient-3 starts consultation with General at 22, waited 18
# Patient-3 finishes consultation at 27
# Patient-4 starts consultation with General at 27, waited 20
# Average doctor waiting time at 30 is 12.0
# Changed doctor type to Specialist at 30
# Patient-4 finishes consultation at 37
# Patient-5 starts consultation with Specialist at 37, waited 28
# Average doctor waiting time at 40 is 14.666666666666666
# Changed doctor type to Specialist at 40
# Patient-5 finishes consultation at 44
# Patient-6 starts consultation with Specialist at 44, waited 34
# Average doctor waiting time at 50 is 17.428571428571427
# Changed doctor type to Specialist at 50
# Patient-6 finishes consultation at 50
# Patient-7 starts consultation with Specialist at 50, waited 36
# Patient-7 finishes consultation at 56
# Patient-8 starts consultation with Specialist at 56, waited 39
# Average doctor waiting time at 60 is 21.88888888888889
# Changed doctor type to Specialist at 60
# Patient-8 finishes consultation at 66
# Patient-9 starts consultation with Specialist at 66, waited 47
# Average doctor waiting time at 70 is 24.4
# Changed doctor type to Specialist at 70
# Patient-9 finishes consultation at 73
# Patient-10 starts consultation with Specialist at 73, waited 52
# Patient-10 finishes consultation at 79
# Patient-11 starts consultation with Specialist at 79, waited 56
# Average doctor waiting time at 80 is 29.333333333333332
# Changed doctor type to Specialist at 80
# Patient-11 finishes consultation at 87
# Patient-12 starts consultation with Specialist at 87, waited 61
# Average doctor waiting time at 90 is 31.76923076923077
# Changed doctor type to Specialist at 90
# Patient-12 finishes consultation at 92
# Patient-13 starts consultation with Specialist at 92, waited 64

# %%
""" bank23: One counter with a priority customer with preemption """
from simpy.Simulation import *
from random import expovariate, seed

## Model components ------------------------

class Source(Process):
    """ Source generates customers randomly """

    def generate(self,number,interval,resource):
        for i in range(number):
            c = Customer(name = "Customer%02d"%(i,))
            activate(c,c.visit(timeInBank=12.0,
                               res=resource,P=0))
            t = expovariate(1.0/interval)
            yield hold,self,t

class Customer(Process):
    """ Customer arrives, is served and  leaves """

    def visit(self,timeInBank=0,res=None,P=0):
        arrive = now()       # arrival time
        Nwaiting = len(res.waitQ)
        print("%8.3f %s: Queue is %d on arrival"%(now(),self.name,Nwaiting))

        yield request,self,res,P
        wait = now()-arrive  # waiting time
        print ("%8.3f %s: Waited %6.3f"%(now(),self.name,wait))
        yield hold,self,timeInBank
        yield release,self,res

        print ("%8.3f %s: Completed"%(now(),self.name))

## Experiment data -------------------------

maxTime = 400.0  # minutes
k = Resource(name="Counter",unitName="Karen",
             qType=PriorityQ, preemptable=True)

## Model/Experiment ------------------------------
seed(98989)
initialize()
s = Source('Source')
activate(s,s.generate(number=5, interval=10.0,
                      resource=k),at=0.0)
guido = Customer(name="Guido     ")
activate(guido,guido.visit(timeInBank=12.0,res=k,
                           P=100),at=23.0)
simulate(until=maxTime)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-4b76953b5585> in <cell line: 2>()
#       1 """ bank23: One counter with a priority customer with preemption """
# ----> 2 from simpy.Simulation import *
#       3 from random import expovariate, seed
#       4
#       5 ## Model components ------------------------
#
# ModuleNotFoundError: No module named 'simpy.Simulation'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import simpy

def resource_user(name, env, resource, wait, prio):
    yield env.timeout(wait)
    with resource.request(priority=prio) as req:
        print(f'{name} requesting at {env.now} with priority={prio}')
        yield req
        print(f'{name} got resource at {env.now}')
        yield env.timeout(3)


env = simpy.Environment()
res = simpy.PriorityResource(env, capacity=1)
p1 = env.process(resource_user(1, env, res, wait=0, prio=5))
p2 = env.process(resource_user(2, env, res, wait=0, prio=2))
p3 = env.process(resource_user(3, env, res, wait=2, prio=1))
env.run()
# Out:
# 1 requesting at 0 with priority=5
# 2 requesting at 0 with priority=2
# 1 got resource at 0
# 3 requesting at 2 with priority=1
# 3 got resource at 3
# 2 got resource at 6

# %%
import simpy

# Define the base class
class HealthcareWorker:
    def __init__(self, env):
        self.env = env

    def work(self):
        raise NotImplementedError("Subclass must implement abstract method")

# Define the subclass Doctor
class Doctor(HealthcareWorker):
    def work(self):
        while True:
            print(f"Doctor starts consulting at {self.env.now}")
            consultation_time = 5  # Doctor spends 5 time units per patient
            yield self.env.timeout(consultation_time)
            print(f"Doctor ends consulting at {self.env.now}")

# Define the subclass Nurse
class Nurse(HealthcareWorker):
    def work(self):
        while True:
            print(f"Nurse starts triage at {self.env.now}")
            triage_time = 3  # Nurse spends 3 time units per patient
            yield self.env.timeout(triage_time)
            print(f"Nurse ends triage at {self.env.now}")

def manage_healthcare_workers(env, workers):
    for worker in workers:
        env.process(worker.work())

# Create the SimPy environment
env = simpy.Environment()

# Instantiate workers
workers = [
    Doctor(env),
    Nurse(env),
]

# Run the management process
env.process(manage_healthcare_workers(env, workers))

# Run the simulation
env.run(until=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-797299b31c01> in <cell line: 43>()
#      41
#      42 # Run the management process
# ---> 43 env.process(manage_healthcare_workers(env, workers))
#      44
#      45 # Run the simulation
#
# /usr/local/lib/python3.10/dist-packages/simpy/events.py in __init__(self, env, generator)
#     337             # with a ``throw`` attribute are generators.
#     338             # Remove this workaround if it causes issues in production!
# --> 339             raise ValueError(f'{generator} is not a generator.')
#     340
#     341         # NOTE: The following initialization code is inlined from
#
# ValueError: None is not a generator.

# %%
total_doctor_wait = 0
num_doctor_visits = 0
waiting_time_threshold = 8  # Time units

class Doctor(simpy.Resource):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "General"

    def add_doctor(self):
        self._capacity += 1

class SpecialistDoctor(Doctor):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "Specialist"

env = simpy.Environment()
John = SpecialistDoctor(env, capacity = 3)

# %%
class g:
  total_general_ophthalmologist_wait = 0
  total_glaucoma_specialist_wait = 0
  total_patients = 5



def GlaucomaPatient(env, name, ophthalmologist, specialist):
    print(f"{name} enters the system at {env.now}")
    # Step 1: General Ophthalmologist visit
    arrival_time = env.now
    with ophthalmologist.request() as req:
        yield req
        wait_time = env.now - arrival_time
        g.total_general_ophthalmologist_wait += wait_time
        print(f"{name} starts visit at general ophtalmologist at {env.now}, waited {wait_time}")
        yield env.timeout(float(np.random.normal(1, 0.1, 1)[0]))
        print(f"{name} finishes visit at general ophthalmologist at {env.now}")

    # Step 2: Doctor Consultation
    arrival_time = env.now
    with specialist.request() as req:
        yield req
        wait_time = env.now - arrival_time
        g.total_glaucoma_specialist_wait += wait_time
        print(f"{name} starts visit at glaucoma specialist at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes visit at glaucoma specialist at {env.now}")


# Initialize SimPy environment
env = simpy.Environment()

# Initialize resources: general ophthalmologist, glaucoma specialist
general_ophthalmologist = simpy.Resource(env, capacity=2)
glaucoma_specialist = simpy.Resource(env, capacity=1)


# Generate 5 patients
for i in range(g.total_patients):
    env.process(GlaucomaPatient(env, f"Patient-{i}", general_ophthalmologist, glaucoma_specialist))

# Run the simulation
env.run()

# Calculate average waiting time for each resource
print("\nAverage waiting times:")
print(f"General Opthalmologist: {g.total_general_ophthalmologist_wait / g.total_patients:.2f}")
print(f"Glaucoma Specialist: {g.total_glaucoma_specialist_wait / g.total_patients:.2f}")
# Out:
# Patient-0 enters the system at 0
# Patient-1 enters the system at 0
# Patient-2 enters the system at 0
# Patient-3 enters the system at 0
# Patient-4 enters the system at 0
# Patient-0 starts visit at general ophtalmologist at 0, waited 0
# Patient-1 starts visit at general ophtalmologist at 0, waited 0
# Patient-0 finishes visit at general ophthalmologist at 0.9240296540356803
# Patient-0 starts visit at glaucoma specialist at 0.9240296540356803, waited 0.0
# Patient-2 starts visit at general ophtalmologist at 0.9240296540356803, waited 0.9240296540356803
# Patient-1 finishes visit at general ophthalmologist at 1.0117514363610665
# Patient-3 starts visit at general ophtalmologist at 1.0117514363610665, waited 1.0117514363610665
# Patient-3 finishes visit at general ophthalmologist at 1.7357302454343568
# Patient-4 starts visit at general ophtalmologist at 1.7357302454343568, waited 1.7357302454343568
# Patient-2 finishes visit at general ophthalmologist at 2.0070558287801026
# Patient-4 finishes visit at general ophthalmologist at 2.838873693184977
# Patient-0 finishes visit at glaucoma specialist at 9.92402965403568
# Patient-1 starts visit at glaucoma specialist at 9.92402965403568, waited 8.912278217674613
# Patient-1 finishes visit at glaucoma specialist at 15.92402965403568
# Patient-3 starts visit at glaucoma specialist at 15.92402965403568, waited 14.188299408601322
# Patient-3 finishes visit at glaucoma specialist at 25.924029654035678
# Patient-2 starts visit at glaucoma specialist at 25.924029654035678, waited 23.916973825255575
# Patient-2 finishes visit at glaucoma specialist at 35.92402965403568
# Patient-4 starts visit at glaucoma specialist at 35.92402965403568, waited 33.0851559608507
# Patient-4 finishes visit at glaucoma specialist at 45.92402965403568
#
# Average waiting times:
# General Opthalmologist: 0.73
# Glaucoma Specialist: 16.02

# %%
class g:
  total_general_ophthalmologist_wait = 0
  total_glaucoma_specialist_wait = 0
  total_patients = 3



def GlaucomaPatient(env, name, ophthalmologist):
    print(f"{name} enters the system at {env.now}")
    # Step 1: General Ophthalmologist visit
    arrival_time = env.now
    with ophthalmologist.request() as req:
        yield req
        wait_time = env.now - arrival_time
        g.total_general_ophthalmologist_wait += wait_time
        print(f"{name} starts visit at general ophtalmologist at {round(env.now,2)}, waited {round(wait_time,2)}")
        yield env.timeout(float(np.random.normal(1, 0.1, 1)[0]))
        print(f"{name} finishes visit at general ophthalmologist at {round(env.now,2)}")


# Initialize SimPy environment
env = simpy.Environment()

# Initialize resources: general ophthalmologist, glaucoma specialist
general_ophthalmologist = simpy.Resource(env, capacity=2)

# Generate 5 patients
for i in range(g.total_patients):
    env.process(GlaucomaPatient(env, f"Patient-{i}", general_ophthalmologist))

# Run the simulation
env.run()

# Calculate average waiting time for each resource
print("\nAverage waiting times:")
#print(f"General Opthalmologist: {g.total_general_ophthalmologist_wait / g.total_patients:.2f}")
#print(f"Glaucoma Specialist: {g.total_glaucoma_specialist_wait / g.total_patients:.2f}")
# Out:
# Patient-0 enters the system at 0
# Patient-1 enters the system at 0
# Patient-2 enters the system at 0
# Patient-0 starts visit at general ophtalmologist at 0, waited 0
# Patient-1 starts visit at general ophtalmologist at 0, waited 0
# Patient-0 finishes visit at general ophthalmologist at 0.98
# Patient-2 starts visit at general ophtalmologist at 0.98, waited 0.98
# Patient-1 finishes visit at general ophthalmologist at 1.06
# Patient-2 finishes visit at general ophthalmologist at 1.88
#
# Average waiting times:

# %%
def monitor(env, doctor):
    global total_doctor_wait, num_doctor_visits
    while True:
        yield env.timeout(10)  # Check every 10 time units
        if num_doctor_visits == 0:
            continue
        avg_wait_time = total_doctor_wait / num_doctor_visits
        print(f"Average doctor waiting time at {env.now} is {avg_wait_time}")
        if avg_wait_time > waiting_time_threshold:
            doctor.capacity += 1  # Add an extra doctor
            print(f"Added an extra doctor at {env.now}, new capacity: {doctor.capacity}")

def patient(env, name, doctor):
    global total_doctor_wait, num_doctor_visits

    arrival_time = env.now
    with doctor.request() as req:
        yield req
        wait_time = env.now - arrival_time
        total_doctor_wait += wait_time
        num_doctor_visits += 1
        print(f"{name} starts consultation at {env.now}, waited {wait_time}")
        yield env.timeout(random.randint(5, 10))
        print(f"{name} finishes consultation at {env.now}")

# Initialize SimPy environment
env = simpy.Environment()

# Initialize doctor resource with initial capacity of 1
doctor = simpy.Resource(env, capacity=1)

# Start the monitoring process
env.process(monitor(env, doctor))

# Generate patients
for i in range(20):
    env.process(patient(env, f"Patient-{i}", doctor))
    next_patient_in = random.randint(1, 4)
    #yield env.timeout(next_patient_in)

# %%
import simpy
import numpy as np

class g:
  total_general_ophthalmologist_wait = 0
  total_glaucoma_specialist_wait = 0
  patient_count = 0
  total_patients = 30
  max_waiting_time = 4
  num_visits = 0
  max_queue_length = 10

def monitor(env, ophthalmologist):
    while True:
        yield env.timeout(2)  # Check every 2 time units
        if g.num_visits == 0:
            continue
        avg_wait_time = g.total_general_ophthalmologist_wait  / g.num_visits
        print(f"Average waiting time at {env.now} is {avg_wait_time}")
        #print(f"Number visits at {env.now} is {g.num_visits}")
        cond1 = avg_wait_time > g.max_waiting_time
        cond2 = len(ophthalmologist.queue) > g.max_queue_length
        if cond1 and cond2:
            ophthalmologist._capacity += 1  # Add an extra resource
            print(f"Added an extra ophthalmologist at {env.now}, new capacity: {ophthalmologist.capacity}")
            with ophthalmologist.request() as req:
              yield env.timeout(0)


def GlaucomaPatient(env, name, ophthalmologist):
    print(f"{name} enters the system at {env.now}")
    # Step 1: General Ophthalmologist visit
    arrival_time = env.now
    with ophthalmologist.request() as req:
        yield req
        wait_time = env.now - arrival_time
        g.num_visits += 1
        g.total_general_ophthalmologist_wait += wait_time
        print(f"{name} starts visit at general ophtalmologist at {round(env.now,2)}, waited {round(wait_time,2)}")
        print(f"Length queue at {env.now} is {len(ophthalmologist.queue)} number of visits is {g.num_visits}")
        yield env.timeout(float(np.random.normal(3, 0.1, 1)[0]))

        print(f"{name} finishes visit at general ophthalmologist at {round(env.now,2)}")


# Initialize SimPy environment
env = simpy.Environment()

# Initialize resources: general ophthalmologist, glaucoma specialist
general_ophthalmologist = simpy.Resource(env, capacity=2)

env.process(monitor(env, general_ophthalmologist))

# Generate 5 patients
for i in range(g.total_patients):
    env.process(GlaucomaPatient(env, f"Patient-{i}", general_ophthalmologist))
    ## have a time laps between patient arrivals
    env.timeout(float(np.random.normal(3, 0.1, 1)[0]))
# Run the simulation
env.run(until = 100)

# Calculate average waiting time for each resource
print("\nAverage waiting times:")
#print(f"General Opthalmologist: {g.total_general_ophthalmologist_wait / g.total_patients:.2f}")
#print(f"Glaucoma Specialist: {g.total_glaucoma_specialist_wait / g.total_patients:.2f}")
# Out:
# Patient-0 enters the system at 0
# Patient-1 enters the system at 0
# Patient-2 enters the system at 0
# Patient-3 enters the system at 0
# Patient-4 enters the system at 0
# Patient-5 enters the system at 0
# Patient-6 enters the system at 0
# Patient-7 enters the system at 0
# Patient-8 enters the system at 0
# Patient-9 enters the system at 0
# Patient-10 enters the system at 0
# Patient-11 enters the system at 0
# Patient-12 enters the system at 0
# Patient-13 enters the system at 0
# Patient-14 enters the system at 0
# Patient-15 enters the system at 0
# Patient-16 enters the system at 0
# Patient-17 enters the system at 0
# Patient-18 enters the system at 0
# Patient-19 enters the system at 0
# Patient-20 enters the system at 0
# Patient-21 enters the system at 0
# Patient-22 enters the system at 0
# Patient-23 enters the system at 0
# Patient-24 enters the system at 0
# Patient-25 enters the system at 0
# Patient-26 enters the system at 0
# Patient-27 enters the system at 0
# Patient-28 enters the system at 0
# Patient-29 enters the system at 0
# Patient-0 starts visit at general ophtalmologist at 0, waited 0
# Length queue at 0 is 28 number of visits is 1
# Patient-1 starts visit at general ophtalmologist at 0, waited 0
# Length queue at 0 is 28 number of visits is 2
# Average waiting time at 2 is 0.0
# Patient-1 finishes visit at general ophthalmologist at 2.69
# Patient-2 starts visit at general ophtalmologist at 2.69, waited 2.69
# Length queue at 2.690142045461444 is 27 number of visits is 3
# Patient-0 finishes visit at general ophthalmologist at 2.89
# Patient-3 starts visit at general ophtalmologist at 2.89, waited 2.89
# Length queue at 2.8945271257010847 is 26 number of visits is 4
# Average waiting time at 4 is 1.3961672927906323
# Patient-2 finishes visit at general ophthalmologist at 5.7
# Patient-4 starts visit at general ophtalmologist at 5.7, waited 5.7
# Length queue at 5.702074318961542 is 25 number of visits is 5
# Patient-3 finishes visit at general ophthalmologist at 5.81
# Patient-5 starts visit at general ophtalmologist at 5.81, waited 5.81
# Length queue at 5.811684541064205 is 24 number of visits is 6
# Average waiting time at 6 is 2.8497380051980463
# Average waiting time at 8 is 2.8497380051980463
# Patient-4 finishes visit at general ophthalmologist at 8.55
# Patient-6 starts visit at general ophtalmologist at 8.55, waited 8.55
# Length queue at 8.54852384291381 is 23 number of visits is 7
# Patient-5 finishes visit at general ophthalmologist at 8.73
# Patient-7 starts visit at general ophtalmologist at 8.73, waited 8.73
# Length queue at 8.732895530760839 is 22 number of visits is 8
# Average waiting time at 10 is 4.297480925607866
# Added an extra ophthalmologist at 10, new capacity: 3
# Patient-8 starts visit at general ophtalmologist at 10, waited 10
# Length queue at 10 is 22 number of visits is 9
# Patient-6 finishes visit at general ophthalmologist at 11.58
# Patient-9 starts visit at general ophtalmologist at 11.58, waited 11.58
# Length queue at 11.579515648739626 is 20 number of visits is 10
# Patient-7 finishes visit at general ophthalmologist at 11.69
# Patient-10 starts visit at general ophtalmologist at 11.69, waited 11.69
# Length queue at 11.692278119895528 is 19 number of visits is 11
# Average waiting time at 12 is 6.150149197590736
# Added an extra ophthalmologist at 12, new capacity: 4
# Patient-11 starts visit at general ophtalmologist at 12, waited 12
# Length queue at 12 is 19 number of visits is 12
# Patient-8 finishes visit at general ophthalmologist at 13.12
# Patient-12 starts visit at general ophtalmologist at 13.12, waited 13.12
# Length queue at 13.11658278535414 is 17 number of visits is 13
# Average waiting time at 14 is 7.136017227604018
# Added an extra ophthalmologist at 14, new capacity: 5
# Patient-13 starts visit at general ophtalmologist at 14, waited 14
# Length queue at 14 is 17 number of visits is 14
# Patient-9 finishes visit at general ophthalmologist at 14.58
# Patient-14 starts visit at general ophtalmologist at 14.58, waited 14.58
# Length queue at 14.58194745548393 is 15 number of visits is 15
# Patient-10 finishes visit at general ophthalmologist at 14.68
# Patient-15 starts visit at general ophtalmologist at 14.68, waited 14.68
# Length queue at 14.677016019955518 is 14 number of visits is 16
# Patient-11 finishes visit at general ophthalmologist at 14.96
# Patient-16 starts visit at general ophtalmologist at 14.96, waited 14.96
# Length queue at 14.959977418753791 is 13 number of visits is 17
# Patient-12 finishes visit at general ophthalmologist at 15.98
# Patient-17 starts visit at general ophtalmologist at 15.98, waited 15.98
# Length queue at 15.983023774520815 is 12 number of visits is 18
# Average waiting time at 16 is 9.276121590420349
# Added an extra ophthalmologist at 16, new capacity: 6
# Patient-18 starts visit at general ophtalmologist at 16, waited 16
# Length queue at 16 is 12 number of visits is 19
# Patient-13 finishes visit at general ophthalmologist at 16.92
# Patient-19 starts visit at general ophtalmologist at 16.92, waited 16.92
# Length queue at 16.915802210550886 is 10 number of visits is 20
# Patient-14 finishes visit at general ophthalmologist at 17.62
# Patient-20 starts visit at general ophtalmologist at 17.62, waited 17.62
# Length queue at 17.617037748668107 is 9 number of visits is 21
# Patient-15 finishes visit at general ophthalmologist at 17.67
# Patient-21 starts visit at general ophtalmologist at 17.67, waited 17.67
# Length queue at 17.669798233105073 is 8 number of visits is 22
# Patient-16 finishes visit at general ophthalmologist at 17.98
# Patient-22 starts visit at general ophtalmologist at 17.98, waited 17.98
# Length queue at 17.981233050037908 is 7 number of visits is 23
# Average waiting time at 18 is 11.006698255214271
# Patient-18 finishes visit at general ophthalmologist at 18.92
# Patient-23 starts visit at general ophtalmologist at 18.92, waited 18.92
# Length queue at 18.918376607179876 is 6 number of visits is 24
# Patient-17 finishes visit at general ophthalmologist at 19.0
# Patient-24 starts visit at general ophtalmologist at 19.0, waited 19.0
# Length queue at 19.004110148583823 is 5 number of visits is 25
# Patient-19 finishes visit at general ophthalmologist at 19.98
# Patient-25 starts visit at general ophtalmologist at 19.98, waited 19.98
# Length queue at 19.982653400117595 is 4 number of visits is 26
# Average waiting time at 20 is 11.96381538560806
# Patient-20 finishes visit at general ophthalmologist at 20.45
# Patient-26 starts visit at general ophtalmologist at 20.45, waited 20.45
# Length queue at 20.452777722020777 is 3 number of visits is 27
# Patient-21 finishes visit at general ophthalmologist at 20.63
# Patient-27 starts visit at general ophtalmologist at 20.63, waited 20.63
# Length queue at 20.628500102410484 is 2 number of visits is 28
# Patient-22 finishes visit at general ophthalmologist at 20.94
# Patient-28 starts visit at general ophtalmologist at 20.94, waited 20.94
# Length queue at 20.937381902040375 is 1 number of visits is 29
# Average waiting time at 22 is 12.86475378456142
# Patient-24 finishes visit at general ophthalmologist at 22.02
# Patient-29 starts visit at general ophtalmologist at 22.02, waited 22.02
# Length queue at 22.02147692667244 is 0 number of visits is 30
# Patient-23 finishes visit at general ophthalmologist at 22.06
# Patient-25 finishes visit at general ophthalmologist at 23.08
# Patient-26 finishes visit at general ophthalmologist at 23.29
# Patient-27 finishes visit at general ophthalmologist at 23.76
# Patient-28 finishes visit at general ophthalmologist at 23.81
# Average waiting time at 24 is 13.169977889298455
# Patient-29 finishes visit at general ophthalmologist at 24.96
# Average waiting time at 26 is 13.169977889298455
# Average waiting time at 28 is 13.169977889298455
# Average waiting time at 30 is 13.169977889298455
# Average waiting time at 32 is 13.169977889298455
# Average waiting time at 34 is 13.169977889298455
# Average waiting time at 36 is 13.169977889298455
# Average waiting time at 38 is 13.169977889298455
# Average waiting time at 40 is 13.169977889298455
# Average waiting time at 42 is 13.169977889298455
# Average waiting time at 44 is 13.169977889298455
# Average waiting time at 46 is 13.169977889298455
# Average waiting time at 48 is 13.169977889298455
# Average waiting time at 50 is 13.169977889298455
# Average waiting time at 52 is 13.169977889298455
# Average waiting time at 54 is 13.169977889298455
# Average waiting time at 56 is 13.169977889298455
# Average waiting time at 58 is 13.169977889298455
# Average waiting time at 60 is 13.169977889298455
# Average waiting time at 62 is 13.169977889298455
# Average waiting time at 64 is 13.169977889298455
# Average waiting time at 66 is 13.169977889298455
# Average waiting time at 68 is 13.169977889298455
# Average waiting time at 70 is 13.169977889298455
# Average waiting time at 72 is 13.169977889298455
# Average waiting time at 74 is 13.169977889298455
# Average waiting time at 76 is 13.169977889298455
# Average waiting time at 78 is 13.169977889298455
# Average waiting time at 80 is 13.169977889298455
# Average waiting time at 82 is 13.169977889298455
# Average waiting time at 84 is 13.169977889298455
# Average waiting time at 86 is 13.169977889298455
# Average waiting time at 88 is 13.169977889298455
# Average waiting time at 90 is 13.169977889298455
# Average waiting time at 92 is 13.169977889298455
# Average waiting time at 94 is 13.169977889298455
# Average waiting time at 96 is 13.169977889298455
# Average waiting time at 98 is 13.169977889298455
#
# Average waiting times:

# %%
import simpy

def monitor(env, resource, add_capacity_event):
    """Monitors the resource usage, and increases capacity if needed."""
    while True:
        yield env.timeout(1)  # Monitor every 10 time units.
        if len(resource.queue) > 2:  # Arbitrary condition to add capacity.
            resource._capacity += 1
            add_capacity_event.succeed()  # Trigger the event to notify processes.
            add_capacity_event = env.event()  # Create a new event for future capacity changes.
            print(f"Resource capacity increased to {resource.capacity} at time {env.now}")

def patient(env, name, resource, add_capacity_event):
    """Patient process that requests a resource."""
    while True:
        with resource.request() as req:
            yield req
            print(f"{name} got resource at time {env.now}")
            yield env.timeout(5)  # Use the resource for 5 time units.
            print(f"{name} released resource at time {env.now}")
            break  # Exit the loop once the resource is used.

        # Wait for the event indicating an increase in resource capacity.
        yield add_capacity_event

env = simpy.Environment()
resource = simpy.PreemptiveResource(env, capacity=1)
add_capacity_event = env.event()  # Event to trigger when capacity is increased.

# Start the monitor and patients.
env.process(monitor(env, resource, add_capacity_event))
for i in range(5):
    env.process(patient(env, f"Patient {i}", resource, add_capacity_event))

env.run(until=100)
# Out:
# Patient 0 got resource at time 0
# Resource capacity increased to 2 at time 1
# Resource capacity increased to 3 at time 2
# Resource capacity increased to 4 at time 3
# Resource capacity increased to 5 at time 4
# Patient 0 released resource at time 5
# Resource capacity increased to 6 at time 5
# Patient 1 got resource at time 5
# Resource capacity increased to 7 at time 6
# Resource capacity increased to 8 at time 7
# Resource capacity increased to 9 at time 8
# Resource capacity increased to 10 at time 9
# Patient 1 released resource at time 10
# Resource capacity increased to 11 at time 10
# Patient 2 got resource at time 10
# Patient 2 released resource at time 15
# Patient 3 got resource at time 15
# Patient 3 released resource at time 20
# Patient 4 got resource at time 20
# Patient 4 released resource at time 25

# %%
float(np.random.normal(3, 0.1, 1)[0])

print(general_ophthalmologist.queue)
# Out:
# []

# %%
import simpy
import random

# Define a process that represents a patient's treatment
def patient_treatment(env, name, room_resource, healthcare_resource):
    print(f"{name} arrives at the healthcare facility at time {env.now}")

    # Request a room for consultation
    with room_resource.request() as room_req:
        yield room_req

        # Request a healthcare professional (doctor or nurse)
        with healthcare_resource.request(priority=1) as healthcare_req:
            yield healthcare_req
            print(f"{name} is in the consultation room with a healthcare professional at time {env.now}")
            yield env.timeout(random.uniform(5, 15))  # Simulate treatment time

    print(f"{name} completes treatment at time {env.now}")

# Create a simulation environment
env = simpy.Environment()

# Create resources representing consultation rooms (3 available) and healthcare professionals (3 available)
room_resource = simpy.Resource(env, capacity=3)
healthcare_resource = simpy.PriorityResource(env, capacity=3)

# Generate patients with random arrival times
for i in range(6):  # Create 6 patients
    arrival_time = random.uniform(0, 10)
    env.process(patient_treatment(env, f"Patient-{i}", room_resource, healthcare_resource))
    yield env.timeout(arrival_time)

# Run the simulation
env.run()
# Out:
#   File "<ipython-input-5-ed2024e68b78>", line 31
#     yield env.timeout(arrival_time)
#     ^
# SyntaxError: 'yield' outside function

# %%
# Request a specialist visit and equipment
    with specialist.request() as specialist_req, \
            equipment.request() as equip_req:
        yield specialist_req & equip_req  # Simultaneous request for both resources

# %%
class Doctor:
    def __init__(self, env, capacity):
        self.resource = simpy.Resource(env, capacity)
        self.doctor_type = "General"

class SpecialistDoctor(Doctor):
    def __init__(self, env, capacity):
        super().__init__(env, capacity)
        self.doctor_type = "Specialist"
